# %%
import pandas as pd

# %%
path_train = "D:\\datasets\\mobile_price_classification\\train.csv"
file = pd.read_csv(path_train)
df = file.copy()
df.sample(10)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1500           1225     0          0.7         1   6       0          60
# 1302           1928     0          2.6         0   5       0           5
# 1010            683     0          0.7         0   5       0          19
# 1882            591     0          2.1         1  18       1          16
# 695             560     1          2.0         1   6       1          57
# 195            1526     0          2.1         0   1       1          23
# 1562           1325     0          1.9         0   2       0          50
# 758            1264     0          2.9         1   2       1          34
# 479            1589     1          2.2         1   2       0          58
# 875            1413     0          0.6         0   0       1          13
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1500    0.1        107        2  ...         10      1567  2423    17    11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.price_range.describe()
# Out:
# count    2000.000000
# mean        1.500000
# std         1.118314
# min         0.000000
# 25%         0.750000
# 50%         1.500000
# 75%         2.250000
# max         3.000000
# Name: price_range, dtype: float64

# %%
label = df.price_range
features = df.drop(['price_range'],axis=1)

# %%
Corr = features.corr()
for col in Corr.columns :
    print(Corr[f'{col}'].sort_values(ascending=False))
    print('-------------------------------------------')
# Out:
# battery_power    1.000000
# talk_time        0.052510
# m_dep            0.034085
# fc               0.033334
# pc               0.031441
# four_g           0.015665
# px_height        0.014901
# three_g          0.011522
# clock_speed      0.011482
# blue             0.011252
# mobile_wt        0.001844
# ram             -0.000653
# int_memory      -0.004004
# wifi            -0.008343
# px_width        -0.008402
# touch_screen    -0.010516
# sc_w            -0.021421
# n_cores         -0.029727
# sc_h            -0.029959
# dual_sim        -0.041847
# Name: battery_power, dtype: float64
# -------------------------------------------
# blue             1.000000
# int_memory       0.041177
# n_cores          0.036161
# dual_sim         0.035198
# ram              0.026351
# clock_speed      0.021419
# talk_time        0.013934
# four_g           0.013443
# battery_power    0.011252
# touch_screen     0.010061
# m_dep            0.004049
# fc               0.003593
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_x = pd.DataFrame(scaler.fit_transform(features),columns=features.columns)
scaled_x.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.902597 -0.990050     0.830779 -1.019184 -0.762495 -1.043966
# 1      -0.495139  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 2      -1.537686  1.010051    -1.253064  0.981177 -0.532099  0.957886
# 3      -1.419319  1.010051     1.198517 -1.019184 -0.992890 -1.043966
# 4       1.325906  1.010051    -0.395011 -1.019184  2.002254  0.957886
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -1.380644  0.340740   1.349249 -1.101971 -1.305750  -1.408949 -1.146784
# 1    1.155024  0.687548  -0.120059 -0.664768 -0.645989   0.585778  1.704465
# 2    0.493546  1.381165   0.134244  0.209639 -0.645989   1.392684  1.074968
# 3   -1.215274  1.034357  -0.261339  0.646842 -0.151168   1.286750  1.236971
# 4    0.658915  0.340740   0.021220 -1.101971  0.673534   1.268718 -0.091452
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# ...

# %%
path_test = "D:\\datasets\\mobile_price_classification\\test.csv"
file_test = pd.read_csv(path_test,index_col=0)
df_test = file_test.copy()
df_test.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
#
#     mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id
# 1         193        3  16        226      1412  3476    12     7          2
# 2         191        5  12        746       857  3895     6     0          7
# 3         186        3   4       1270      1366  2396    17    10         10
# 4          96        8  20        295      1752  3893    10     0          7
# 5         108        6  18        749       810  1773    15     8          7
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1000 non-null   int64
#  1   blue           1000 non-null   int64
#  2   clock_speed    1000 non-null   float64
#  3   dual_sim       1000 non-null   int64
#  4   fc             1000 non-null   int64
#  5   four_g         1000 non-null   int64
#  6   int_memory     1000 non-null   int64
#  7   m_dep          1000 non-null   float64
#  8   mobile_wt      1000 non-null   int64
#  9   n_cores        1000 non-null   int64
#  10  pc             1000 non-null   int64
#  11  px_height      1000 non-null   int64
#  12  px_width       1000 non-null   int64
#  13  ram            1000 non-null   int64
#  14  sc_h           1000 non-null   int64
#  15  sc_w           1000 non-null   int64
#  16  talk_time      1000 non-null   int64
#  17  three_g        1000 non-null   int64
# ...

# %%
scaled_test = pd.DataFrame(scaler.fit_transform(df_test),columns=df_test.columns)

# %%
from sklearn.model_selection import train_test_split
xtr , xts , ytr , yts = train_test_split(scaled_x,label,test_size=0.01,random_state=32)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression().fit(xtr,ytr)

# %%
model.score(xtr,ytr)*100
# Out:
# 97.92929292929293

# %%
model.score(xts,yts)*100
# Out:
# 95.0

# %%
model.score(scaled_x,label)*100
# Out:
# 97.89999999999999

# %%
preds = model.predict(scaled_test)

# %%
preds[:11]
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3], dtype=int64)
